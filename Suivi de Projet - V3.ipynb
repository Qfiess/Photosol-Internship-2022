# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import (FigureCanvasTkAgg, 
NavigationToolbar2Tk)
import numpy as np
import pvlib
import rdtools
# %matplotlib inline
from rdtools.soiling import monthly_soiling_rates
from rdtools.soiling import annual_soiling_ratios
from pandastable import Table, TableModel, config

import tkinter as tk
from tkinter import *
from tkinter import ttk
from tkinter import simpledialog
from tkinter.messagebox import showinfo
# from tkinter.tix import *
from PIL import Image, ImageTk

import pathlib
import os
import shutil

import openpyxl as xl
from openpyxl import load_workbook
import re

import xlwings as xw
import pickle
import time
# Out:
# C:\Users\quentin.fiessinger\Anaconda3\lib\site-packages\rdtools\soiling.py:14: UserWarning: The soiling module is currently experimental. The API, results, and default behaviors may change in future releases (including MINOR and PATCH releases) as the code matures.
#   warnings.warn(

# %%
def location():

    test = []

    for cell in sheet.range('A18:A1000'):
        if cell.value != None:
            test.append([cell.value, cell.address[3:len(cell.address)]])


    range1_1 = str("B" + str(int(test[0][1]) + 1)  + ":B" + str(int(test[1][1]) - 5))
    range1_2 = str("C" + test[0][1]  + ":C" + str(int(test[1][1]) - 5))
    range1_3 = str("K" + str(int(test[0][1]))  + ":K" + str(int(test[1][1]) - 5))
    range1_4 = str("M" + str(int(test[0][1]))  + ":M" + str(int(test[1][1]) - 5))
    range1_5 = str("N" + str(int(test[0][1]))  + ":N" + str(int(test[1][1]) - 5))
    range1_6 = str("D" + str(int(test[0][1]))  + ":D" + str(int(test[1][1]) - 5))

    crce = []

    for cell in sheet.range(range1_1):
        crce.append([cell.value, 0, 0, 0, 0, 0, cell.address[3:len(cell.address)]])
        
    counter1_1 = 0
    for cell in sheet.range(range1_2):
        crce[counter1_1 - 1][1] = cell.value
        if counter1_1 < len(crce):
            counter1_1 += 1

    counter1_2 = 0
    for cell in sheet.range(range1_3):
        crce[counter1_2 - 1][3] = cell.value
        if counter1_2 < len(crce):
            counter1_2 += 1

    counter1_3 = 0
    for cell in sheet.range(range1_4):
        crce[counter1_3 - 1][4] = str(cell.value)[0:10]
        if counter1_3 < len(crce):
            counter1_3 += 1

    counter1_4 = 0
    for cell in sheet.range(range1_5):
        crce[counter1_4 - 1][5] = cell.value
        if counter1_4 < len(crce):
            counter1_4 += 1

    counter1_5 = 0
    for cell in sheet.range(range1_6):
        crce[counter1_5 - 1][2] = cell.value
        if counter1_5 < len(crce):
            counter1_5 += 1


    range2_1 = str("B" + str(int(test[1][1]) + 1)  + ":B" + str(int(test[2][1]) - 5))
    range2_2 = str("C" + test[1][1]  + ":C" + str(int(test[2][1]) - 5))
    range2_3 = str("K" + test[1][1]  + ":K" + str(int(test[2][1]) - 5))
    range2_4 = str("M" + test[1][1]  + ":M" + str(int(test[2][1]) - 5))
    range2_5 = str("N" + test[1][1]  + ":N" + str(int(test[2][1]) - 5))
    range2_6 = str("D" + test[1][1]  + ":D" + str(int(test[2][1]) - 5))

    cmdl = []

    for cell in sheet.range(range2_1):
        cmdl.append([cell.value, 0, 0, 0, 0, 0, cell.address[3:len(cell.address)]])

            
    counter1_1 = 0
    for cell in sheet.range(range2_2):
        cmdl[counter1_1 - 1][1] = cell.value
        if counter1_1 < len(cmdl):
            counter1_1 += 1

    counter1_2 = 0
    for cell in sheet.range(range2_3):
        cmdl[counter1_2 - 1][3] = cell.value
        if counter1_2 < len(cmdl):
            counter1_2 += 1

    counter1_3 = 0
    for cell in sheet.range(range2_4):
        cmdl[counter1_3 - 1][4] = str(cell.value)[0:10]
        if counter1_3 < len(cmdl):
            counter1_3 += 1

    counter1_4 = 0
    for cell in sheet.range(range2_5):
        cmdl[counter1_4 - 1][5] = cell.value
        if counter1_4 < len(cmdl):
            counter1_4 += 1

    counter1_5 = 0
    for cell in sheet.range(range2_6):
        cmdl[counter1_5 - 1][2] = cell.value
        if counter1_5 < len(cmdl):
            counter1_5 += 1        


    range3_1 = str("B" + str(int(test[2][1]) + 1)  + ":B" + str(int(test[3][1]) - 5))
    range3_2 = str("C" + test[2][1]  + ":C" + str(int(test[3][1]) - 5))
    range3_3 = str("K" + test[2][1]  + ":K" + str(int(test[3][1]) - 5))
    range3_4 = str("M" + test[2][1]  + ":M" + str(int(test[3][1]) - 5))
    range3_5 = str("N" + test[2][1]  + ":N" + str(int(test[3][1]) - 5))
    range3_6 = str("D" + test[2][1]  + ":D" + str(int(test[3][1]) - 5))

    cclx = []

    for cell in sheet.range(range3_1):
        cclx.append([cell.value, 0, 0, 0, 0, 0, cell.address[3:len(cell.address)]])

    counter1_1 = 0
    for cell in sheet.range(range3_2):
        cclx[counter1_1 - 1][1] = cell.value
        if counter1_1 < len(cclx):
            counter1_1 += 1

    counter1_2 = 0
    for cell in sheet.range(range3_3):
        cclx[counter1_2 - 1][3] = cell.value
        if counter1_2 < len(cclx):
            counter1_2 += 1

    counter1_3 = 0
    for cell in sheet.range(range3_4):
        cclx[counter1_3 - 1][4] = str(cell.value)[0:10]
        if counter1_3 < len(cclx):
            counter1_3 += 1

    counter1_4 = 0
    for cell in sheet.range(range3_5):
        cclx[counter1_4 - 1][5] = cell.value
        if counter1_4 < len(cclx):
            counter1_4 += 1

    counter1_5 = 0
    for cell in sheet.range(range3_6):
        cclx[counter1_5 - 1][2] = cell.value
        if counter1_5 < len(cclx):
            counter1_5 += 1

    range4_1 = str("B" + str(int(test[3][1]) + 1)  + ":B" + str(int(test[4][1]) - 5))
    range4_2 = str("C" + test[3][1]  + ":C" + str(int(test[4][1]) - 5))
    range4_3 = str("K" + test[3][1]  + ":K" + str(int(test[4][1]) - 5))
    range4_4 = str("M" + test[3][1]  + ":M" + str(int(test[4][1]) - 5))
    range4_5 = str("N" + test[3][1]  + ":N" + str(int(test[4][1]) - 5))
    range4_6 = str("D" + test[3][1]  + ":D" + str(int(test[4][1]) - 5))

    cgem = []

    for cell in sheet.range(range4_1):
        cgem.append([cell.value, 0, 0, 0, 0, 0, cell.address[3:len(cell.address)]])

    counter1_1 = 0
    for cell in sheet.range(range4_2):
        cgem[counter1_1 - 1][1] = cell.value
        if counter1_1 < len(cgem):
            counter1_1 += 1

    counter1_2 = 0
    for cell in sheet.range(range4_3):
        cgem[counter1_2 - 1][3] = cell.value
        if counter1_2 < len(cgem):
            counter1_2 += 1

    counter1_3 = 0
    for cell in sheet.range(range4_4):
        cgem[counter1_3 - 1][4] = str(cell.value)[0:10]
        if counter1_3 < len(cgem):
            counter1_3 += 1

    counter1_4 = 0
    for cell in sheet.range(range4_5):
        cgem[counter1_4 - 1][5] = cell.value
        if counter1_4 < len(cgem):
            counter1_4 += 1

    counter1_5 = 0
    for cell in sheet.range(range4_6):
        cgem[counter1_5 - 1][2] = cell.value
        if counter1_5 < len(cgem):
            counter1_5 += 1 

    range5_1 = str("B" + str(int(test[4][1]) + 1)  + ":B" + str(int(test[5][1]) - 5))
    range5_2 = str("C" + test[4][1]  + ":C" + str(int(test[5][1]) - 5))
    range5_3 = str("K" + test[4][1]  + ":K" + str(int(test[5][1]) - 5))
    range5_4 = str("M" + test[4][1]  + ":M" + str(int(test[5][1]) - 5))
    range5_5 = str("N" + test[4][1]  + ":N" + str(int(test[5][1]) - 5))
    range5_6 = str("D" + test[4][1]  + ":D" + str(int(test[5][1]) - 5))

    cgel = []

    for cell in sheet.range(range5_1):
        cgel.append([cell.value, 0, 0, 0, 0, 0, cell.address[3:len(cell.address)]])

    counter1_1 = 0
    for cell in sheet.range(range5_2):
        cgel[counter1_1 - 1][1] = cell.value
        if counter1_1 < len(cgel):
            counter1_1 += 1

    counter1_2 = 0
    for cell in sheet.range(range5_3):
        cgel[counter1_2 - 1][3] = cell.value
        if counter1_2 < len(cgel):
            counter1_2 += 1

    counter1_3 = 0
    for cell in sheet.range(range5_4):
        cgel[counter1_3 - 1][4] = str(cell.value)[0:10]
        if counter1_3 < len(cgel):
            counter1_3 += 1

    counter1_4 = 0
    for cell in sheet.range(range5_5):
        cgel[counter1_4 - 1][5] = cell.value
        if counter1_4 < len(cgel):
            counter1_4 += 1

    counter1_5 = 0
    for cell in sheet.range(range5_6):
        cgel[counter1_5 - 1][2] = cell.value
        if counter1_5 < len(cgel):
            counter1_5 += 1 

    range6_1 = str("B" + str(int(test[5][1]) + 1)  + ":B" + str(190))
    range6_2 = str("C" + test[5][1]  + ":C" + str(190))
    range6_3 = str("K" + test[5][1]  + ":K" + str(190))
    range6_4 = str("M" + test[5][1]  + ":M" + str(190))
    range6_5 = str("N" + test[5][1]  + ":N" + str(190))
    range6_6 = str("D" + test[5][1]  + ":D" + str(190))

    cter = []

    for cell in sheet.range(range6_1):
        cter.append([cell.value, 0, 0, 0, 0, 0, cell.address[3:len(cell.address)]])

    counter1_1 = 0
    for cell in sheet.range(range6_2):
        cter[counter1_1 - 1][1] = cell.value
        if counter1_1 < len(cter):
            counter1_1 += 1

    counter1_2 = 0
    for cell in sheet.range(range6_3):
        cter[counter1_2 - 1][3] = cell.value
        if counter1_2 < len(cter):
            counter1_2 += 1

    counter1_3 = 0
    for cell in sheet.range(range6_4):
        cter[counter1_3 - 1][4] = str(cell.value)[0:10]
        if counter1_3 < len(cter):
            counter1_3 += 1

    counter1_4 = 0
    for cell in sheet.range(range6_5):
        cter[counter1_4 - 1][5] = cell.value
        if counter1_4 < len(cter):
            counter1_4 += 1

    counter1_5 = 0
    for cell in sheet.range(range6_6):
        cter[counter1_5 - 1][2] = cell.value
        if counter1_5 < len(cter):
            counter1_5 += 1


    print()
    print(cter)   
    
    return crce, cmdl, cclx, cgem, cgel, cter

# %%
def ajouter(self, parent, controller):
    global rang
    global ranger
    rang = ttk.Label(self, text = "Entrer la ligne en question").grid(row = 5, column = 1, pady = 1)
    ranger = ttk.Entry(self)
    ranger.grid(row = 6, column = 1, padx = 10, pady = 1)

    global l
    global lot
    l = ttk.Label(self, text = "Entrer la nouvelle lot").grid(row = 7, column = 1, pady = 1)
    lot = ttk.Entry(self)
    lot.grid(row = 8, column = 1, padx = 10, pady = 1)
    
    global lib
    global libelle
    lib = ttk.Label(self, text = "Entrer la nouvelle libelle").grid(row = 11, column = 1, pady = 1)
    libelle = ttk.Entry(self)
    libelle.grid(row = 12, column = 1, padx = 10, pady = 1)

    global cont
    global contractant
    cont = ttk.Label(self, text = "Entrer le nouveau contractant").grid(row = 9, column = 1, pady = 1)
    contractant = ttk.Entry(self)
    contractant.grid(row = 10, column = 1, padx = 10, pady = 1)

    global montc
    global montantCon
    montc = ttk.Label(self, text = "Entrer le nouveau montant contractuel").grid(row = 13, column = 1, pady = 1)
    montantCon = ttk.Entry(self)
    montantCon.grid(row = 14, column = 1, padx = 10, pady = 1)

    global date
    global dateprevue
    date = ttk.Label(self, text = "Entrer la nouvelle date prevue").grid(row = 15, column = 1, pady = 1)
    dateprevue = ttk.Entry(self)
    dateprevue.grid(row = 16, column = 1, padx = 10, pady = 1)

    global montr
    global montantRea
    montr = ttk.Label(self, text = "Entrer le nouveau montant realise").grid(row = 17, column = 1, pady = 1)
    montantRea = ttk.Entry(self)
    montantRea.grid(row = 18, column = 1, padx = 10, pady = 1)

# %%
def ajouter2(self, parent, controller):
    global rang2
    global ranger2
    rang2 = ttk.Label(self, text = "Entrer l'emplacement de la nouvelle ligne").grid(row = 5, column = 1, pady = 1)
    ranger2 = ttk.Entry(self)
    ranger2.grid(row = 6, column = 1, padx = 10, pady = 1)

    global l2
    global lot2
    l2 = ttk.Label(self, text = "Entrer la nouvelle lot").grid(row = 7, column = 1, pady = 1)
    lot2 = ttk.Entry(self)
    lot2.grid(row = 8, column = 1, padx = 10, pady = 1)
    
    global lib2
    global libelle2
    lib2 = ttk.Label(self, text = "Entrer la nouvelle libelle").grid(row = 11, column = 1, pady = 1)
    libelle2 = ttk.Entry(self)
    libelle2.grid(row = 12, column = 1, padx = 10, pady = 1)

    global cont2
    global contractant2
    cont2 = ttk.Label(self, text = "Entrer le nouveau contractant").grid(row = 9, column = 1, pady = 1)
    contractant2 = ttk.Entry(self)
    contractant2.grid(row = 10, column = 1, padx = 10, pady = 1)

    global montc2
    global montantCon2
    montc2 = ttk.Label(self, text = "Entrer le nouveau montant contractuel").grid(row = 13, column = 1, pady = 1)
    montantCon2 = ttk.Entry(self)
    montantCon2.grid(row = 14, column = 1, padx = 10, pady = 1)

    global date2
    global dateprevue2
    date2 = ttk.Label(self, text = "Entrer la nouvelle date prevue").grid(row = 15, column = 1, pady = 1)
    dateprevue2 = ttk.Entry(self)
    dateprevue2.grid(row = 16, column = 1, padx = 10, pady = 1)

    global montr2
    global montantRea2
    montr2 = ttk.Label(self, text = "Entrer le nouveau montant realise").grid(row = 17, column = 1, pady = 1)
    montantRea2 = ttk.Entry(self)
    montantRea2.grid(row = 18, column = 1, padx = 10, pady = 1)

# %%
LARGEFONT =("Verdana", 15)
  
class tkinterApp(tk.Tk):
     
    # __init__ function for class tkinterApp
    def __init__(self, *args, **kwargs):
         
        # __init__ function for class Tk
        tk.Tk.__init__(self, *args, **kwargs)
        
        self.geometry("1400x800")
        
        global wb
        wb = xw.Book(r"C:\Users\quentin.fiessinger\Documents\C01-suivi projet.xlsx")
        global sheet
        sheet = wb.sheets['7. Suivi Budget']
    
        # creating a container
        container = tk.Frame(self) 
        container.pack(side = "top", fill = "both", expand = True)
  
        container.grid_rowconfigure(0, weight = 1)
        container.grid_columnconfigure(0, weight = 1)
  
        # initializing frames to an empty array
        self.frames = {} 
  
        # iterating through a tuple consisting
        # of the different page layouts
        for F in (StartPage, Page1, Page2, Page3, Page4, Page5, Page6):
  
            frame = F(container, self)
  
            # initializing frame of that object from
            # startpage, page1, page2 respectively with
            # for loop
            self.frames[F] = frame
  
            frame.grid(row = 0, column = 0, sticky ="nsew")
  
        self.show_frame(StartPage)
  
    # to display the current frame passed as
    # parameter
    def show_frame(self, cont):
        frame = self.frames[cont]
        frame.tkraise()

# first window frame startpage
  
class StartPage(tk.Frame):
    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
         
        # label of frame Layout 2
        label = ttk.Label(self, text = "Startpage", font = LARGEFONT)
        label.grid(row = 0, column = 0, padx = 10, pady = 1)        

        button = ttk.Button(self, text ="StartPage",
                            command = lambda : controller.show_frame(StartPage))
        button.grid(row = 1, column = 0, padx = 10, pady = 1)
          
        button1 = ttk.Button(self, text ="Raccordement électrique",
                            command = lambda : controller.show_frame(Page1))
        button1.grid(row = 2, column = 0, padx = 10, pady = 1)
  
        button2 = ttk.Button(self, text ="Modules",
                            command = lambda : controller.show_frame(Page2))
        button2.grid(row = 3, column = 0, padx = 10, pady = 1)
  
        button3 = ttk.Button(self, text ="Frais de constructions divers",
                            command = lambda : controller.show_frame(Page3))
        button3.grid(row = 4, column = 0, padx = 10, pady = 1)
        
        button4 = ttk.Button(self, text ="Génie mécanique  - Structure/Fixation",
                            command = lambda : controller.show_frame(Page4))
        button4.grid(row = 5, column = 0, padx = 10, pady = 1)
  
        button5 = ttk.Button(self, text ="Génie éléctrique",
                            command = lambda : controller.show_frame(Page5))
        button5.grid(row = 6, column = 0, padx = 10, pady = 1)
        
        button6 = ttk.Button(self, text ="Terrassement/Voirie",
                            command = lambda : controller.show_frame(Page6))
        button6.grid(row = 7, column = 0, padx = 10, pady = 1)
        
        def save():
            wb.save()
            wb.close()
        
        button7 = ttk.Button(self, text ="Enregister changement aux ficher", command = save)
        button7.grid(row = 2, column = 1)
          
  
  
# second window frame page1
class Page1(tk.Frame):
     
    def __init__(self, parent, controller):
         
        tk.Frame.__init__(self, parent)

        
        label = ttk.Label(self, text ="Raccordement électrique", font = LARGEFONT)
        label.grid(row = 0, column = 0, padx = 10, pady = 1)
  
        # button to show frame 2 with text
        # layout2
        
        def Display1():

            for widgets in Page1.winfo_children(self):
                widgets.destroy()
                print("success")
                
            for i in range(0, len(crce)):
                for j in range(0, len(crce[0])):
                    ttk.Label(self, text = crce[i][j]).grid(row = i + 1, column = j + 2, padx = 10, pady = 1)
                    
            label = ttk.Label(self, text ="Raccordement électrique", font = LARGEFONT)
            label.grid(row = 0, column = 0, padx = 10, pady = 1)
            
            label1 = ttk.Label(self, text ="Lot")
            label1.grid(row = 0, column = 2, padx = 10, pady = 1)

            label2 = ttk.Label(self, text ="Contractant")
            label2.grid(row = 0, column = 3, padx = 10, pady = 1)

            label3 = ttk.Label(self, text ="Info Paiement")
            label3.grid(row = 0, column = 4, padx = 10, pady = 1)

            label4 = ttk.Label(self, text ="Montant Contractuel")
            label4.grid(row = 0, column = 5, padx = 10, pady = 1)

            label5 = ttk.Label(self, text ="Date Prevue")
            label5.grid(row = 0, column = 6, padx = 10, pady = 1)

            label5 = ttk.Label(self, text ="Montant Realise")
            label5.grid(row = 0, column = 7, padx = 10, pady = 1)
            
            label6 = ttk.Label(self, text ="Ligne")
            label6.grid(row = 0, column = 8, padx = 10, pady = 1)
            
            display = ttk.Button(self, text = "affichage", command = Display1)
            display.grid(row = 2, column = 1, padx = 5, pady = 1)

            button = ttk.Button(self, text ="StartPage",
                                command = lambda : controller.show_frame(StartPage))
            button.grid(row = 1, column = 0, padx = 10, pady = 1)

            button1 = ttk.Button(self, text ="Raccordement électrique",
                                command = lambda : controller.show_frame(Page1))
            button1.grid(row = 2, column = 0, padx = 10, pady = 1)

            button2 = ttk.Button(self, text ="Modules",
                                command = lambda : controller.show_frame(Page2))
            button2.grid(row = 3, column = 0, padx = 10, pady = 1)

            button3 = ttk.Button(self, text ="Frais de constructions divers",
                                command = lambda : controller.show_frame(Page3))
            button3.grid(row = 4, column = 0, padx = 10, pady = 1)

            button4 = ttk.Button(self, text ="Génie mécanique  - Structure/Fixation",
                                command = lambda : controller.show_frame(Page4))
            button4.grid(row = 5, column = 0, padx = 10, pady = 1)

            button5 = ttk.Button(self, text ="Génie éléctrique",
                                command = lambda : controller.show_frame(Page5))
            button5.grid(row = 6, column = 0, padx = 10, pady = 1)

            button6 = ttk.Button(self, text ="Terrassement/Voirie",
                                command = lambda : controller.show_frame(Page6))
            button6.grid(row = 7, column = 0, padx = 10, pady = 1)
            
            def Update1_2():
                global crce
                global cmdl
                global cclx
                global cgem
                global cgel
                global cter
                
                crce, cmdl, cclx, cgem, cgel, cter = location() 
                Display1()      
                
            def test(choice):
                choice = clicked.get()
                
                def addition():
                    global ranger
                    global libelle
                    global contractant
                    global montantCon
                    global dateprevue
                    global montantRea
                    global sheet
                    global lot
                    
                    global crce
                    global cmdl
                    global cclx
                    global cgem
                    global cgel
                    global cter
                    
                    for i in range(0, len(crce)):
                        if crce[i][6] == ranger.get():
                            if contractant.get() != "":
                                location1 = "C"  + str(crce[i][6])
                                sheet.range(location1).value = contractant.get()
                            if libelle.get() != "":
                                location1 = "D"  + str(crce[i][6])
                                sheet.range(location1).value = libelle.get()
                            if montantCon.get() != "":
                                location1 = "K"  + str(crce[i][6])
                                sheet.range(location1).value = montantCon.get()
                            if dateprevue.get() != "":
                                location1 = "M"  + str(crce[i][6])
                                sheet.range(location1).value = dateprevue.get()
                            if montantRea.get() != "":
                                location1 = "N"  + str(crce[i][6])
                                sheet.range(location1).value = montantRea.get()
                            if lot.get() != "":
                                location1 = "B"  + str(crce[i][6])
                                sheet.range(location1).value = lot.get()    
                            
                    Update1_2()
                    
                def addition2():
                    global ranger2
                    global libelle2
                    global contractant2
                    global montantCon2
                    global dateprevue2
                    global montantRea2
                    global sheet
                    global lot2
                    
                    global crce
                    global cmdl
                    global cclx
                    global cgem
                    global cgel
                    global cter
                    
                    ligneloc = str(ranger2.get()) + ":" + str(ranger2.get())
                    sheet.range(ligneloc).insert('down')
                    
                    if contractant2.get() != "":
                        location1 = "C"  + str(ranger2.get())
                        sheet.range(location1).value = contractant2.get()
                    if libelle2.get() != "":
                        location1 = "D"  + str(ranger2.get())
                        sheet.range(location1).value = libelle2.get()
                    if montantCon2.get() != "":
                        location1 = "K"  + str(ranger2.get())
                        sheet.range(location1).value = montantCon2.get()
                    if dateprevue2.get() != "":
                        location1 = "M"  + str(ranger2.get())
                        sheet.range(location1).value = dateprevue2.get()
                    if montantRea2.get() != "":
                        location1 = "N"  + str(ranger2.get())
                        sheet.range(location1).value = montantRea2.get()
                    if lot2.get() != "":
                        location1 = "B"  + str(ranger2.get())
                        sheet.range(location1).value = lot2.get()
                                
                    Update1_2()
                                
                if choice == "Changer une facture existante":
                    ajouter(self, parent, controller)
                    
                    global ranger
                    global libelle
                    global contractant
                    global montantCon
                    global dateprevue
                    global montantRea
                
                        
                    button = ttk.Button(self, text = "Finaliser",
                                command = addition)
                    button.grid(row = 19, column = 1, padx = 10, pady = 10)
                
                elif choice == "Rajouter une nouvelle facture":
                    global sheet
                    ajouter2(self, parent, controller)
                    
                    global ranger2
                    global libelle2
                    global contractant2
                    global montantCon2
                    global dateprevue2
                    global montantRea2
                    
                    button = ttk.Button(self, text = "Finaliser",
                                command = addition2)
                    button.grid(row = 19, column = 1, padx = 10, pady = 10)
                        
            options = [
                "Changer une facture existante",
                "Rajouter une nouvelle facture"
            ]

            global clicked
            clicked = StringVar()
            clicked.set("Bonus options")

            drop2 = OptionMenu(self, clicked, *options, command = test)
            drop2.grid(row = 4, column = 1, padx = 10, pady = 1)
            
            
        display = ttk.Button(self, text = "Affichage", command = Display1)
        display.grid(row = 2, column = 1, padx = 5, pady = 1)
           
        button = ttk.Button(self, text ="StartPage",
                            command = lambda : controller.show_frame(StartPage))
        button.grid(row = 1, column = 0, padx = 10, pady = 1)
          
        button1 = ttk.Button(self, text ="Raccordement électrique",
                            command = lambda : controller.show_frame(Page1))
        button1.grid(row = 2, column = 0, padx = 10, pady = 1)
  
        button2 = ttk.Button(self, text ="Modules",
                            command = lambda : controller.show_frame(Page2))
        button2.grid(row = 3, column = 0, padx = 10, pady = 1)
  
        button3 = ttk.Button(self, text ="Frais de constructions divers",
                            command = lambda : controller.show_frame(Page3))
        button3.grid(row = 4, column = 0, padx = 10, pady = 1)
        
        button4 = ttk.Button(self, text ="Génie mécanique  - Structure/Fixation",
                            command = lambda : controller.show_frame(Page4))
        button4.grid(row = 5, column = 0, padx = 10, pady = 1)
  
        button5 = ttk.Button(self, text ="Génie éléctrique",
                            command = lambda : controller.show_frame(Page5))
        button5.grid(row = 6, column = 0, padx = 10, pady = 1)
        
        button6 = ttk.Button(self, text ="Terrassement/Voirie",
                            command = lambda : controller.show_frame(Page6))
        button6.grid(row = 7, column = 0, padx = 10, pady = 1)
        
# third window frame page2
class Page2(tk.Frame):
    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
    
        label = ttk.Label(self, text ="Modules", font = LARGEFONT)
        label.grid(row = 0, column = 0, padx = 10, pady = 1)        
        
        def Display2_1():
            for widgets in Page2.winfo_children(self):
                widgets.destroy()
            
            for i in range(0, len(cmdl)):
                for j in range(0, len(cmdl[0])):
                    ttk.Label(self, text = cmdl[i][j]).grid(row = i + 1, column = j + 2, padx = 10, pady = 1)
                    
            label = ttk.Label(self, text ="Modules", font = LARGEFONT)
            label.grid(row = 0, column = 0, padx = 10, pady = 1)
            
            label1 = ttk.Label(self, text ="Lot")
            label1.grid(row = 0, column = 2, padx = 10, pady = 1)

            label2 = ttk.Label(self, text ="Contractant")
            label2.grid(row = 0, column = 3, padx = 10, pady = 1)

            label3 = ttk.Label(self, text ="Info Paiement")
            label3.grid(row = 0, column = 4, padx = 10, pady = 1)

            label4 = ttk.Label(self, text ="Montant Contractuel")
            label4.grid(row = 0, column = 5, padx = 10, pady = 1)

            label5 = ttk.Label(self, text ="Date Prevue")
            label5.grid(row = 0, column = 6, padx = 10, pady = 1)

            label5 = ttk.Label(self, text ="Montant Realise")
            label5.grid(row = 0, column = 7, padx = 10, pady = 1)
            
            label6 = ttk.Label(self, text ="Ligne")
            label6.grid(row = 0, column = 8, padx = 10, pady = 1)
            
            display = ttk.Button(self, text = "Affichage", command = Display2_1)
            display.grid(row = 2, column = 1, padx = 5, pady = 1)

            button = ttk.Button(self, text ="StartPage",
                                command = lambda : controller.show_frame(StartPage))
            button.grid(row = 1, column = 0, padx = 10, pady = 1)

            button1 = ttk.Button(self, text ="Raccordement électrique",
                                command = lambda : controller.show_frame(Page1))
            button1.grid(row = 2, column = 0, padx = 10, pady = 1)

            button2 = ttk.Button(self, text ="Modules",
                                command = lambda : controller.show_frame(Page2))
            button2.grid(row = 3, column = 0, padx = 10, pady = 1)

            button3 = ttk.Button(self, text ="Frais de constructions divers",
                                command = lambda : controller.show_frame(Page3))
            button3.grid(row = 4, column = 0, padx = 10, pady = 1)

            button4 = ttk.Button(self, text ="Génie mécanique  - Structure/Fixation",
                                command = lambda : controller.show_frame(Page4))
            button4.grid(row = 5, column = 0, padx = 10, pady = 1)

            button5 = ttk.Button(self, text ="Génie éléctrique",
                                command = lambda : controller.show_frame(Page5))
            button5.grid(row = 6, column = 0, padx = 10, pady = 1)

            button6 = ttk.Button(self, text ="Terrassement/Voirie",
                                command = lambda : controller.show_frame(Page6))
            button6.grid(row = 7, column = 0, padx = 10, pady = 1)

            def Update2_2():
                global crce
                global cmdl
                global cclx
                global cgem
                global cgel
                global cter
  
                crce, cmdl, cclx, cgem, cgel, cter = location() 
                Display2_1()
        
            def test(choice):
                choice = clicked.get()
                
                def addition():
                    global ranger
                    global libelle
                    global contractant
                    global montantCon
                    global dateprevue
                    global montantRea
                    global sheet
                    global lot
                    
                    global crce
                    global cmdl
                    global cclx
                    global cgem
                    global cgel
                    global cter
                    
                    for i in range(0, len(cmdl)):
                        if cmdl[i][6] == ranger.get():
                            if contractant.get() != "":
                                location1 = "C"  + str(cmdl[i][6])
                                sheet.range(location1).value = contractant.get()
                            if libelle.get() != "":
                                location1 = "D"  + str(cmdl[i][6])
                                sheet.range(location1).value = libelle.get()
                            if montantCon.get() != "":
                                location1 = "K"  + str(cmdl[i][6])
                                sheet.range(location1).value = montantCon.get()
                            if dateprevue.get() != "":
                                location1 = "M"  + str(cmdl[i][6])
                                sheet.range(location1).value = dateprevue.get()
                            if montantRea.get() != "":
                                location1 = "N"  + str(cmdl[i][6])
                                sheet.range(location1).value = montantRea.get()
                            if lot.get() != "":
                                location1 = "B"  + str(crce[i][6])
                                sheet.range(location1).value = lot.get()
                                
                    Update2_2()
                    
                def addition2():
                    global ranger2
                    global libelle2
                    global contractant2
                    global montantCon2
                    global dateprevue2
                    global montantRea2
                    global sheet
                    global lot2
                    
                    global crce
                    global cmdl
                    global cclx
                    global cgem
                    global cgel
                    global cter
                    
                    ligneloc = str(ranger2.get()) + ":" + str(ranger2.get())
                    sheet.range(ligneloc).insert('down')
                    
                    if contractant2.get() != "":
                        location1 = "C"  + str(ranger2.get())
                        sheet.range(location1).value = contractant2.get()
                    if libelle2.get() != "":
                        location1 = "D"  + str(ranger2.get())
                        sheet.range(location1).value = libelle2.get()
                    if montantCon2.get() != "":
                        location1 = "K"  + str(ranger2.get())
                        sheet.range(location1).value = montantCon2.get()
                    if dateprevue2.get() != "":
                        location1 = "M"  + str(ranger2.get())
                        sheet.range(location1).value = dateprevue2.get()
                    if montantRea2.get() != "":
                        location1 = "N"  + str(ranger2.get())
                        sheet.range(location1).value = montantRea2.get()
                    if lot2.get() != "":
                        location1 = "B"  + str(ranger2.get())
                        sheet.range(location1).value = lot2.get()
                                
                    Update2_2()
                                
                if choice == "Changer une facture existante":
                    ajouter(self, parent, controller)
                    
                    global ranger
                    global libelle
                    global contractant
                    global montantCon
                    global dateprevue
                    global montantRea
                
                        
                    button = ttk.Button(self, text = "Finaliser",
                                command = addition)
                    button.grid(row = 19, column = 1, padx = 10, pady = 10)
                
                elif choice == "Rajouter une nouvelle facture":
                    global sheet
                    ajouter2(self, parent, controller)
                    
                    global ranger2
                    global libelle2
                    global contractant2
                    global montantCon2
                    global dateprevue2
                    global montantRea2
                    
                    button = ttk.Button(self, text = "Finaliser",
                                command = addition2)
                    button.grid(row = 19, column = 1, padx = 10, pady = 10)
                        
            options = [
                "Changer une facture existante",
                "Rajouter une nouvelle facture"
            ]

            global clicked
            clicked = StringVar()
            clicked.set("Bonus options")

            drop2 = OptionMenu(self, clicked, *options, command = test)
            drop2.grid(row = 4, column = 1, padx = 10, pady = 1)
            

        display = ttk.Button(self, text = "Affichage", command = Display2_1)
        display.grid(row = 2, column = 1, padx = 5, pady = 1)
        
        button = ttk.Button(self, text ="StartPage",
                            command = lambda : controller.show_frame(StartPage))
        button.grid(row = 1, column = 0, padx = 10, pady = 1)
          
        button1 = ttk.Button(self, text ="Raccordement électrique",
                            command = lambda : controller.show_frame(Page1))
        button1.grid(row = 2, column = 0, padx = 10, pady = 1)
  
        button2 = ttk.Button(self, text ="Modules",
                            command = lambda : controller.show_frame(Page2))
        button2.grid(row = 3, column = 0, padx = 10, pady = 1)
  
        button3 = ttk.Button(self, text ="Frais de constructions divers",
                            command = lambda : controller.show_frame(Page3))
        button3.grid(row = 4, column = 0, padx = 10, pady = 1)
        
        button4 = ttk.Button(self, text ="Génie mécanique  - Structure/Fixation",
                            command = lambda : controller.show_frame(Page4))
        button4.grid(row = 5, column = 0, padx = 10, pady = 1)
  
        button5 = ttk.Button(self, text ="Génie éléctrique",
                            command = lambda : controller.show_frame(Page5))
        button5.grid(row = 6, column = 0, padx = 10, pady = 1)
        
        button6 = ttk.Button(self, text ="Terrassement/Voirie",
                            command = lambda : controller.show_frame(Page6))
        button6.grid(row = 7, column = 0, padx = 10, pady = 1)
        
# third window frame page2
class Page3(tk.Frame):
    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        label = ttk.Label(self, text ="Frais de constructions divers", font = LARGEFONT)
        label.grid(row = 0, column = 0, padx = 10, pady = 1)


        def Display3_1():
            for widgets in Page3.winfo_children(self):
                widgets.destroy()
        
            for i in range(0, len(cclx)):
                for j in range(0, len(cclx[0])):
                    ttk.Label(self, text = cclx[i][j]).grid(row = i + 1, column = j + 2, padx = 10, pady = 1)
                    
            label = ttk.Label(self, text ="Frais de constructions divers", font = LARGEFONT)
            label.grid(row = 0, column = 0, padx = 10, pady = 1)
            
            label1 = ttk.Label(self, text ="Lot")
            label1.grid(row = 0, column = 2, padx = 10, pady = 1)

            label2 = ttk.Label(self, text ="Contractant")
            label2.grid(row = 0, column = 3, padx = 10, pady = 1)

            label3 = ttk.Label(self, text ="Info Paiement")
            label3.grid(row = 0, column = 4, padx = 10, pady = 1)

            label4 = ttk.Label(self, text ="Montant Contractuel")
            label4.grid(row = 0, column = 5, padx = 10, pady = 1)

            label5 = ttk.Label(self, text ="Date Prevue")
            label5.grid(row = 0, column = 6, padx = 10, pady = 1)

            label5 = ttk.Label(self, text ="Montant Realise")
            label5.grid(row = 0, column = 7, padx = 10, pady = 1)
            
            label6 = ttk.Label(self, text ="Ligne")
            label6.grid(row = 0, column = 8, padx = 10, pady = 1)
                
            display = ttk.Button(self, text = "Affichage", command = Display3_1)
            display.grid(row = 2, column = 1, padx = 5, pady = 1)

            button = ttk.Button(self, text ="StartPage",
                                command = lambda : controller.show_frame(StartPage))
            button.grid(row = 1, column = 0, padx = 10, pady = 1)

            button1 = ttk.Button(self, text ="Raccordement électrique",
                                command = lambda : controller.show_frame(Page1))
            button1.grid(row = 2, column = 0, padx = 10, pady = 1)

            button2 = ttk.Button(self, text ="Modules",
                                command = lambda : controller.show_frame(Page2))
            button2.grid(row = 3, column = 0, padx = 10, pady = 1)

            button3 = ttk.Button(self, text ="Frais de constructions divers",
                                command = lambda : controller.show_frame(Page3))
            button3.grid(row = 4, column = 0, padx = 10, pady = 1)

            button4 = ttk.Button(self, text ="Génie mécanique  - Structure/Fixation",
                                command = lambda : controller.show_frame(Page4))
            button4.grid(row = 5, column = 0, padx = 10, pady = 1)

            button5 = ttk.Button(self, text ="Génie éléctrique",
                                command = lambda : controller.show_frame(Page5))
            button5.grid(row = 6, column = 0, padx = 10, pady = 1)

            button6 = ttk.Button(self, text ="Terrassement/Voirie",
                                command = lambda : controller.show_frame(Page6))
            button6.grid(row = 7, column = 0, padx = 10, pady = 1)
        
            def Update3_1():
                global crce
                global cmdl
                global cclx
                global cgem
                global cgel
                global cter
                
                crce, cmdl, cclx, cgem, cgel, cter = location() 
                Display3_1()
                
            def test(choice):
                choice = clicked.get()
                
                def addition():
                    global ranger
                    global libelle
                    global contractant
                    global montantCon
                    global dateprevue
                    global montantRea
                    global sheet
                    global lot
                    
                    global crce
                    global cmdl
                    global cclx
                    global cgem
                    global cgel
                    global cter
                    
                    for i in range(0, len(cclx)):
                        if cclx[i][6] == ranger.get():
                            if contractant.get() != "":
                                location1 = "C"  + str(cclx[i][6])
                                sheet.range(location1).value = contractant.get()
                            if libelle.get() != "":
                                location1 = "D"  + str(cclx[i][6])
                                sheet.range(location1).value = libelle.get()
                            if montantCon.get() != "":
                                location1 = "K"  + str(cclx[i][6])
                                sheet.range(location1).value = montantCon.get()
                            if dateprevue.get() != "":
                                location1 = "M"  + str(cclx[i][6])
                                sheet.range(location1).value = dateprevue.get()
                            if montantRea.get() != "":
                                location1 = "N"  + str(cclx[i][6])
                                sheet.range(location1).value = montantRea.get()
                            if lot.get() != "":
                                location1 = "B"  + str(crce[i][6])
                                sheet.range(location1).value = lot.get()

                                
                    Update3_1()
                    
                def addition2():
                    global ranger2
                    global libelle2
                    global contractant2
                    global montantCon2
                    global dateprevue2
                    global montantRea2
                    global sheet
                    global lot2
                    
                    global crce
                    global cmdl
                    global cclx
                    global cgem
                    global cgel
                    global cter
                    
                    ligneloc = str(ranger2.get()) + ":" + str(ranger2.get())
                    sheet.range(ligneloc).insert('down')
                    
                    if contractant2.get() != "":
                        location1 = "C"  + str(ranger2.get())
                        sheet.range(location1).value = contractant2.get()
                    if libelle2.get() != "":
                        location1 = "D"  + str(ranger2.get())
                        sheet.range(location1).value = libelle2.get()
                    if montantCon2.get() != "":
                        location1 = "K"  + str(ranger2.get())
                        sheet.range(location1).value = montantCon2.get()
                    if dateprevue2.get() != "":
                        location1 = "M"  + str(ranger2.get())
                        sheet.range(location1).value = dateprevue2.get()
                    if montantRea2.get() != "":
                        location1 = "N"  + str(ranger2.get())
                        sheet.range(location1).value = montantRea2.get()
                    if lot2.get() != "":
                        location1 = "B"  + str(ranger2.get())
                        sheet.range(location1).value = lot2.get()
                        
                    Update3_1()
                                
                if choice == "Changer une facture existante":
                    ajouter(self, parent, controller)
                    
                    global ranger
                    global libelle
                    global contractant
                    global montantCon
                    global dateprevue
                    global montantRea
                
                        
                    button = ttk.Button(self, text = "Finaliser",
                                command = addition)
                    button.grid(row = 19, column = 1, padx = 10, pady = 10)
                
                elif choice == "Rajouter une nouvelle facture":
                    global sheet
                    ajouter2(self, parent, controller)
                    
                    global ranger2
                    global libelle2
                    global contractant2
                    global montantCon2
                    global dateprevue2
                    global montantRea2
                    
                    button = ttk.Button(self, text = "Finaliser",
                                command = addition2)
                    button.grid(row = 19, column = 1, padx = 10, pady = 10)
                        
            options = [
                "Changer une facture existante",
                "Rajouter une nouvelle facture"
            ]

            global clicked
            clicked = StringVar()
            clicked.set("Bonus options")

            drop2 = OptionMenu(self, clicked, *options, command = test)
            drop2.grid(row = 4, column = 1, padx = 10, pady = 1)
        
        
        display = ttk.Button(self, text = "Affichage", command = Display3_1)
        display.grid(row = 2, column = 1, padx = 5, pady = 1)

        button = ttk.Button(self, text ="StartPage",
                            command = lambda : controller.show_frame(StartPage))
        button.grid(row = 1, column = 0, padx = 10, pady = 1)
          
        button1 = ttk.Button(self, text ="Raccordement électrique",
                            command = lambda : controller.show_frame(Page1))
        button1.grid(row = 2, column = 0, padx = 10, pady = 1)
  
        button2 = ttk.Button(self, text ="Modules",
                            command = lambda : controller.show_frame(Page2))
        button2.grid(row = 3, column = 0, padx = 10, pady = 1)
  
        button3 = ttk.Button(self, text ="Frais de constructions divers",
                            command = lambda : controller.show_frame(Page3))
        button3.grid(row = 4, column = 0, padx = 10, pady = 1)
        
        button4 = ttk.Button(self, text ="Génie mécanique  - Structure/Fixation",
                            command = lambda : controller.show_frame(Page4))
        button4.grid(row = 5, column = 0, padx = 10, pady = 1)
  
        button5 = ttk.Button(self, text ="Génie éléctrique",
                            command = lambda : controller.show_frame(Page5))
        button5.grid(row = 6, column = 0, padx = 10, pady = 1)
        
        button6 = ttk.Button(self, text ="Terrassement/Voirie",
                            command = lambda : controller.show_frame(Page6))
        button6.grid(row = 7, column = 0, padx = 10, pady = 1)
        
# third window frame page2
class Page4(tk.Frame):
    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        label = ttk.Label(self, text ="Génie mécanique  - Structure/Fixation", font = LARGEFONT)
        label.grid(row = 0, column = 0, padx = 10, pady = 1)
  

        def Display4_1():
            for widgets in Page4.winfo_children(self):
                widgets.destroy()
                
            for i in range(0, len(cgem)):
                for j in range(0, len(cgem[0])):
                    ttk.Label(self, text = cgem[i][j]).grid(row = i + 1, column = j + 2, padx = 10, pady = 1)
                    
            label = ttk.Label(self, text ="Génie mécanique  - Structure/Fixation", font = LARGEFONT)
            label.grid(row = 0, column = 0, padx = 10, pady = 1)
            
            label1 = ttk.Label(self, text ="Lot")
            label1.grid(row = 0, column = 2, padx = 10, pady = 1)

            label2 = ttk.Label(self, text ="Contractant")
            label2.grid(row = 0, column = 3, padx = 10, pady = 1)

            label3 = ttk.Label(self, text ="Info Paiement")
            label3.grid(row = 0, column = 4, padx = 10, pady = 1)

            label4 = ttk.Label(self, text ="Montant Contractuel")
            label4.grid(row = 0, column = 5, padx = 10, pady = 1)

            label5 = ttk.Label(self, text ="Date Prevue")
            label5.grid(row = 0, column = 6, padx = 10, pady = 1)

            label5 = ttk.Label(self, text ="Montant Realise")
            label5.grid(row = 0, column = 7, padx = 10, pady = 1)
            
            label6 = ttk.Label(self, text ="Ligne")
            label6.grid(row = 0, column = 8, padx = 10, pady = 1)

            display = ttk.Button(self, text = "Affichage", command = Display4_1)
            display.grid(row = 2, column = 1, padx = 5, pady = 1)

            button = ttk.Button(self, text ="StartPage",
                                command = lambda : controller.show_frame(StartPage))
            button.grid(row = 1, column = 0, padx = 10, pady = 1)

            button1 = ttk.Button(self, text ="Raccordement électrique",
                                command = lambda : controller.show_frame(Page1))
            button1.grid(row = 2, column = 0, padx = 10, pady = 1)

            button2 = ttk.Button(self, text ="Modules",
                                command = lambda : controller.show_frame(Page2))
            button2.grid(row = 3, column = 0, padx = 10, pady = 1)

            button3 = ttk.Button(self, text ="Frais de constructions divers",
                                command = lambda : controller.show_frame(Page3))
            button3.grid(row = 4, column = 0, padx = 10, pady = 1)

            button4 = ttk.Button(self, text ="Génie mécanique  - Structure/Fixation",
                                command = lambda : controller.show_frame(Page4))
            button4.grid(row = 5, column = 0, padx = 10, pady = 1)

            button5 = ttk.Button(self, text ="Génie éléctrique",
                                command = lambda : controller.show_frame(Page5))
            button5.grid(row = 6, column = 0, padx = 10, pady = 1)

            button6 = ttk.Button(self, text ="Terrassement/Voirie",
                                command = lambda : controller.show_frame(Page6))
            button6.grid(row = 7, column = 0, padx = 10, pady = 1)
        
            def Update4_1():
                global crce
                global cmdl
                global cclx
                global cgem
                global cgel
                global cter
 
                crce, cmdl, cclx, cgem, cgel, cter = location() 
                Display4_1()        
            
            def test(choice):
                choice = clicked.get()
                
                def addition():
                    global ranger
                    global libelle
                    global contractant
                    global montantCon
                    global dateprevue
                    global montantRea
                    global sheet
                    global lot
                    
                    global crce
                    global cmdl
                    global cclx
                    global cgem
                    global cgel
                    global cter
                    
                    for i in range(0, len(cgem)):
                        if cgem[i][6] == ranger.get():
                            if contractant.get() != "":
                                location1 = "C"  + str(cgem[i][6])
                                sheet.range(location1).value = contractant.get()
                            if libelle.get() != "":
                                location1 = "D"  + str(cgem[i][6])
                                sheet.range(location1).value = libelle.get()
                            if montantCon.get() != "":
                                location1 = "K"  + str(cgem[i][6])
                                sheet.range(location1).value = montantCon.get()
                            if dateprevue.get() != "":
                                location1 = "M"  + str(cgem[i][6])
                                sheet.range(location1).value = dateprevue.get()
                            if montantRea.get() != "":
                                location1 = "N"  + str(cgem[i][6])
                                sheet.range(location1).value = montantRea.get()
                            if lot.get() != "":
                                location1 = "B"  + str(crce[i][6])
                                sheet.range(location1).value = lot.get()

                    Update4_1()
                    
                def addition2():
                    global ranger2
                    global libelle2
                    global contractant2
                    global montantCon2
                    global dateprevue2
                    global montantRea2
                    global sheet
                    global lot2
                    
                    global crce
                    global cmdl
                    global cclx
                    global cgem
                    global cgel
                    global cter
                    
                    ligneloc = str(ranger2.get()) + ":" + str(ranger2.get())
                    sheet.range(ligneloc).insert('down')
                    
                    if contractant2.get() != "":
                        location1 = "C"  + str(ranger2.get())
                        sheet.range(location1).value = contractant2.get()
                    if libelle2.get() != "":
                        location1 = "D"  + str(ranger2.get())
                        sheet.range(location1).value = libelle2.get()
                    if montantCon2.get() != "":
                        location1 = "K"  + str(ranger2.get())
                        sheet.range(location1).value = montantCon2.get()
                    if dateprevue2.get() != "":
                        location1 = "M"  + str(ranger2.get())
                        sheet.range(location1).value = dateprevue2.get()
                    if montantRea2.get() != "":
                        location1 = "N"  + str(ranger2.get())
                        sheet.range(location1).value = montantRea2.get()
                    if lot2.get() != "":
                        location1 = "B"  + str(ranger2.get())
                        sheet.range(location1).value = lot2.get()
                                            
                    Update4_1()
                                
                if choice == "Changer une facture existante":
                    ajouter(self, parent, controller)
                    
                    global ranger
                    global libelle
                    global contractant
                    global montantCon
                    global dateprevue
                    global montantRea
                
                        
                    button = ttk.Button(self, text = "Finaliser",
                                command = addition)
                    button.grid(row = 19, column = 1, padx = 10, pady = 10)
                
                elif choice == "Rajouter une nouvelle facture":
                    global sheet
                    ajouter2(self, parent, controller)
                    
                    global ranger2
                    global libelle2
                    global contractant2
                    global montantCon2
                    global dateprevue2
                    global montantRea2
                    
                    button = ttk.Button(self, text = "Finaliser",
                                command = addition2)
                    button.grid(row = 19, column = 1, padx = 10, pady = 10)
                        
            options = [
                "Changer une facture existante",
                "Rajouter une nouvelle facture"
            ]

            global clicked
            clicked = StringVar()
            clicked.set("Bonus options")

            drop2 = OptionMenu(self, clicked, *options, command = test)
            drop2.grid(row = 4, column = 1, padx = 10, pady = 1)
        

        
        display = ttk.Button(self, text = "Affichage", command = Display4_1)
        display.grid(row = 2, column = 1, padx = 5, pady = 1)

        button = ttk.Button(self, text ="StartPage",
                            command = lambda : controller.show_frame(StartPage))
        button.grid(row = 1, column = 0, padx = 10, pady = 1)
          
        button1 = ttk.Button(self, text ="Raccordement électrique",
                            command = lambda : controller.show_frame(Page1))
        button1.grid(row = 2, column = 0, padx = 10, pady = 1)
  
        button2 = ttk.Button(self, text ="Modules",
                            command = lambda : controller.show_frame(Page2))
        button2.grid(row = 3, column = 0, padx = 10, pady = 1)
  
        button3 = ttk.Button(self, text ="Frais de constructions divers",
                            command = lambda : controller.show_frame(Page3))
        button3.grid(row = 4, column = 0, padx = 10, pady = 1)
        
        button4 = ttk.Button(self, text ="Génie mécanique  - Structure/Fixation",
                            command = lambda : controller.show_frame(Page4))
        button4.grid(row = 5, column = 0, padx = 10, pady = 1)
  
        button5 = ttk.Button(self, text ="Génie éléctrique",
                            command = lambda : controller.show_frame(Page5))
        button5.grid(row = 6, column = 0, padx = 10, pady = 1)
        
        button6 = ttk.Button(self, text ="Terrassement/Voirie",
                            command = lambda : controller.show_frame(Page6))
        button6.grid(row = 7, column = 0, padx = 10, pady = 1)

        # third window frame page2
class Page5(tk.Frame):
    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        label = ttk.Label(self, text ="Génie éléctrique", font = LARGEFONT)
        label.grid(row = 0, column = 0, padx = 10, pady = 1)
  

        def Display5_1():
            for widgets in Page5.winfo_children(self):
                widgets.destroy()
        
            for i in range(0, len(cgel)):
                for j in range(0, len(cgel[0])):
                    ttk.Label(self, text = cgel[i][j]).grid(row = i + 1, column = j + 2, padx = 10, pady = 1)
                    
            label = ttk.Label(self, text ="Génie éléctrique", font = LARGEFONT)
            label.grid(row = 0, column = 0, padx = 10, pady = 1)
            
            label1 = ttk.Label(self, text ="Lot")
            label1.grid(row = 0, column = 2, padx = 10, pady = 1)

            label2 = ttk.Label(self, text ="Contractant")
            label2.grid(row = 0, column = 3, padx = 10, pady = 1)

            label3 = ttk.Label(self, text ="Info Paiement")
            label3.grid(row = 0, column = 4, padx = 10, pady = 1)

            label4 = ttk.Label(self, text ="Montant Contractuel")
            label4.grid(row = 0, column = 5, padx = 10, pady = 1)

            label5 = ttk.Label(self, text ="Date Prevue")
            label5.grid(row = 0, column = 6, padx = 10, pady = 1)

            label5 = ttk.Label(self, text ="Montant Realise")
            label5.grid(row = 0, column = 7, padx = 10, pady = 1)
            
            label6 = ttk.Label(self, text ="Ligne")
            label6.grid(row = 0, column = 8, padx = 10, pady = 1)

            display = ttk.Button(self, text = "Affichage", command = Display5_1)
            display.grid(row = 2, column = 1, padx = 5, pady = 1)

            button = ttk.Button(self, text ="StartPage",
                                command = lambda : controller.show_frame(StartPage))
            button.grid(row = 1, column = 0, padx = 10, pady = 1)

            button1 = ttk.Button(self, text ="Raccordement électrique",
                                command = lambda : controller.show_frame(Page1))
            button1.grid(row = 2, column = 0, padx = 10, pady = 1)

            button2 = ttk.Button(self, text ="Modules",
                                command = lambda : controller.show_frame(Page2))
            button2.grid(row = 3, column = 0, padx = 10, pady = 1)

            button3 = ttk.Button(self, text ="Frais de constructions divers",
                                command = lambda : controller.show_frame(Page3))
            button3.grid(row = 4, column = 0, padx = 10, pady = 1)

            button4 = ttk.Button(self, text ="Génie mécanique  - Structure/Fixation",
                                command = lambda : controller.show_frame(Page4))
            button4.grid(row = 5, column = 0, padx = 10, pady = 1)

            button5 = ttk.Button(self, text ="Génie éléctrique",
                                command = lambda : controller.show_frame(Page5))
            button5.grid(row = 6, column = 0, padx = 10, pady = 1)

            button6 = ttk.Button(self, text ="Terrassement/Voirie",
                                command = lambda : controller.show_frame(Page6))
            button6.grid(row = 7, column = 0, padx = 10, pady = 1)

            def Update5_1():
                global crce
                global cmdl
                global cclx
                global cgem
                global cgel
                global cter
 
                crce, cmdl, cclx, cgem, cgel, cter = location() 
                Display5_1()
        
            def test(choice):
                choice = clicked.get()
                
                def addition():
                    global ranger
                    global libelle
                    global contractant
                    global montantCon
                    global dateprevue
                    global montantRea
                    global sheet
                    global lot
                    
                    global crce
                    global cmdl
                    global cclx
                    global cgem
                    global cgel
                    global cter
                    
                    for i in range(0, len(cgel)):
                        if cgel[i][6] == ranger.get():
                            if contractant.get() != "":
                                location1 = "C"  + str(cgel[i][6])
                                sheet.range(location1).value = contractant.get()
                            if libelle.get() != "":
                                location1 = "D"  + str(cgel[i][6])
                                sheet.range(location1).value = libelle.get()
                            if montantCon.get() != "":
                                location1 = "K"  + str(cgel[i][6])
                                sheet.range(location1).value = montantCon.get()
                            if dateprevue.get() != "":
                                location1 = "M"  + str(cgel[i][6])
                                sheet.range(location1).value = dateprevue.get()
                            if montantRea.get() != "":
                                location1 = "N"  + str(cgel[i][6])
                                sheet.range(location1).value = montantRea.get()
                            if lot.get() != "":
                                location1 = "B"  + str(crce[i][6])
                                sheet.range(location1).value = lot.get()

                    Update5_1()
                    
                def addition2():
                    global ranger2
                    global libelle2
                    global contractant2
                    global montantCon2
                    global dateprevue2
                    global montantRea2
                    global sheet
                    global lot2
                    
                    global crce
                    global cmdl
                    global cclx
                    global cgem
                    global cgel
                    global cter
                    
                    ligneloc = str(ranger2.get()) + ":" + str(ranger2.get())
                    sheet.range(ligneloc).insert('down')
                    
                    if contractant2.get() != "":
                        location1 = "C"  + str(ranger2.get())
                        sheet.range(location1).value = contractant2.get()
                    if libelle2.get() != "":
                        location1 = "D"  + str(ranger2.get())
                        sheet.range(location1).value = libelle2.get()
                    if montantCon2.get() != "":
                        location1 = "K"  + str(ranger2.get())
                        sheet.range(location1).value = montantCon2.get()
                    if dateprevue2.get() != "":
                        location1 = "M"  + str(ranger2.get())
                        sheet.range(location1).value = dateprevue2.get()
                    if montantRea2.get() != "":
                        location1 = "N"  + str(ranger2.get())
                        sheet.range(location1).value = montantRea2.get()
                    if lot2.get() != "":
                        location1 = "B"  + str(ranger2.get())
                        sheet.range(location1).value = lot2.get()
                                            
                    Update5_1()
                                
                if choice == "Changer une facture existante":
                    ajouter(self, parent, controller)
                    
                    global ranger
                    global libelle
                    global contractant
                    global montantCon
                    global dateprevue
                    global montantRea
                
                        
                    button = ttk.Button(self, text = "Finaliser",
                                command = addition)
                    button.grid(row = 19, column = 1, padx = 10, pady = 1)
                
                elif choice == "Rajouter une nouvelle facture":
                    global sheet
                    ajouter2(self, parent, controller)
                    
                    global ranger2
                    global libelle2
                    global contractant2
                    global montantCon2
                    global dateprevue2
                    global montantRea2
                    
                    button = ttk.Button(self, text = "Finaliser",
                                command = addition2)
                    button.grid(row = 19, column = 1, padx = 10, pady = 1)
                        
            options = [
                "Changer une facture existante",
                "Rajouter une nouvelle facture"
            ]

            global clicked
            clicked = StringVar()
            clicked.set("Bonus options")

            drop2 = OptionMenu(self, clicked, *options, command = test)
            drop2.grid(row = 4, column = 1, padx = 10, pady = 1)
            
        display = ttk.Button(self, text = "Affichage", command = Display5_1)
        display.grid(row = 2, column = 1, padx = 5, pady = 1)

        button = ttk.Button(self, text ="StartPage",
                            command = lambda : controller.show_frame(StartPage))
        button.grid(row = 1, column = 0, padx = 10, pady = 1)
          
        button1 = ttk.Button(self, text ="Raccordement électrique",
                            command = lambda : controller.show_frame(Page1))
        button1.grid(row = 2, column = 0, padx = 10, pady = 1)
  
        button2 = ttk.Button(self, text ="Modules",
                            command = lambda : controller.show_frame(Page2))
        button2.grid(row = 3, column = 0, padx = 10, pady = 1)
  
        button3 = ttk.Button(self, text ="Frais de constructions divers",
                            command = lambda : controller.show_frame(Page3))
        button3.grid(row = 4, column = 0, padx = 10, pady = 1)
        
        button4 = ttk.Button(self, text ="Génie mécanique  - Structure/Fixation",
                            command = lambda : controller.show_frame(Page4))
        button4.grid(row = 5, column = 0, padx = 10, pady = 1)
  
        button5 = ttk.Button(self, text ="Génie éléctrique",
                            command = lambda : controller.show_frame(Page5))
        button5.grid(row = 6, column = 0, padx = 10, pady = 1)
        
        button6 = ttk.Button(self, text ="Terrassement/Voirie",
                            command = lambda : controller.show_frame(Page6))
        button6.grid(row = 7, column = 0, padx = 10, pady = 1)
        
# third window frame page2
class Page6(tk.Frame):
    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        label = ttk.Label(self, text ="Terrassement/Voirie", font = LARGEFONT)
        label.grid(row = 0, column = 0, padx = 10, pady = 1)

        
        def Display6_1():
            for widgets in Page5.winfo_children(self):
                widgets.destroy()
            
            for i in range(0, len(cter)):
                if cter[i + 2][4] == "Ecart":
                    break
                for j in range(0, len(cter[0])):
                    ttk.Label(self, text = cter[i][j]).grid(row = i + 1, column = j + 2, padx = 10, pady = 1)
        
            label = ttk.Label(self, text ="Terrassement/Voirie", font = LARGEFONT)
            label.grid(row = 0, column = 0, padx = 10, pady = 1)
            
            label1 = ttk.Label(self, text ="Lot")
            label1.grid(row = 0, column = 2, padx = 10, pady = 1)

            label2 = ttk.Label(self, text ="Contractant")
            label2.grid(row = 0, column = 3, padx = 10, pady = 1)

            label3 = ttk.Label(self, text ="Info Paiement")
            label3.grid(row = 0, column = 4, padx = 10, pady = 1)

            label4 = ttk.Label(self, text ="Montant Contractuel")
            label4.grid(row = 0, column = 5, padx = 10, pady = 1)

            label5 = ttk.Label(self, text ="Date Prevue")
            label5.grid(row = 0, column = 6, padx = 10, pady = 1)

            label5 = ttk.Label(self, text ="Montant Realise")
            label5.grid(row = 0, column = 7, padx = 10, pady = 1)
            
            label6 = ttk.Label(self, text ="Ligne")
            label6.grid(row = 0, column = 8, padx = 10, pady = 1)

            display = ttk.Button(self, text = "Affichage", command = Display6_1)
            display.grid(row = 2, column = 1, padx = 5, pady = 1)

            button = ttk.Button(self, text ="StartPage",
                                command = lambda : controller.show_frame(StartPage))
            button.grid(row = 1, column = 0, padx = 10, pady = 1)

            button1 = ttk.Button(self, text ="Raccordement électrique",
                                command = lambda : controller.show_frame(Page1))
            button1.grid(row = 2, column = 0, padx = 10, pady = 1)

            button2 = ttk.Button(self, text ="Modules",
                                command = lambda : controller.show_frame(Page2))
            button2.grid(row = 3, column = 0, padx = 10, pady = 1)

            button3 = ttk.Button(self, text ="Frais de constructions divers",
                                command = lambda : controller.show_frame(Page3))
            button3.grid(row = 4, column = 0, padx = 10, pady = 1)

            button4 = ttk.Button(self, text ="Génie mécanique  - Structure/Fixation",
                                command = lambda : controller.show_frame(Page4))
            button4.grid(row = 5, column = 0, padx = 10, pady = 1)

            button5 = ttk.Button(self, text ="Génie éléctrique",
                                command = lambda : controller.show_frame(Page5))
            button5.grid(row = 6, column = 0, padx = 10, pady = 1)

            button6 = ttk.Button(self, text ="Terrassement/Voirie",
                                command = lambda : controller.show_frame(Page6))
            button6.grid(row = 7, column = 0, padx = 10, pady = 1)
        
            def Update6_1():
                global crce
                global cmdl
                global cclx
                global cgem
                global cgel
                global cter
                
                crce, cmdl, cclx, cgem, cgel, cter = location() 
                Display6_1()        

            def test(choice):
                choice = clicked.get()
                
                def addition():
                    global ranger
                    global libelle
                    global contractant
                    global montantCon
                    global dateprevue
                    global montantRea
                    global sheet
                    global lot
                    
                    global crce
                    global cmdl
                    global cclx
                    global cgem
                    global cgel
                    global cter
                    
                    for i in range(0, len(cter)):
                        if cter[i][6] == ranger.get():
                            if contractant.get() != "":
                                location1 = "C"  + str(cter[i][6])
                                sheet.range(location1).value = contractant.get()
                            if libelle.get() != "":
                                location1 = "D"  + str(cter[i][6])
                                sheet.range(location1).value = libelle.get()
                            if montantCon.get() != "":
                                location1 = "K"  + str(cter[i][6])
                                sheet.range(location1).value = montantCon.get()
                            if dateprevue.get() != "":
                                location1 = "M"  + str(cter[i][6])
                                sheet.range(location1).value = dateprevue.get()
                            if montantRea.get() != "":
                                location1 = "N"  + str(cter[i][6])
                                sheet.range(location1).value = montantRea.get()
                            if lot.get() != "":
                                location1 = "B"  + str(crce[i][6])
                                sheet.range(location1).value = lot.get()
      
                    Update6_1()
                    
                def addition2():
                    global ranger2
                    global libelle2
                    global contractant2
                    global montantCon2
                    global dateprevue2
                    global montantRea2
                    global sheet
                    global lot2
                    
                    global crce
                    global cmdl
                    global cclx
                    global cgem
                    global cgel
                    global cter
                    
                    ligneloc = str(ranger2.get()) + ":" + str(ranger2.get())
                    sheet.range(ligneloc).insert('down')
                    
                    if contractant2.get() != "":
                        location1 = "C"  + str(ranger2.get())
                        sheet.range(location1).value = contractant2.get()
                    if libelle2.get() != "":
                        location1 = "D"  + str(ranger2.get())
                        sheet.range(location1).value = libelle2.get()
                    if montantCon2.get() != "":
                        location1 = "K"  + str(ranger2.get())
                        sheet.range(location1).value = montantCon2.get()
                    if dateprevue2.get() != "":
                        location1 = "M"  + str(ranger2.get())
                        sheet.range(location1).value = dateprevue2.get()
                    if montantRea2.get() != "":
                        location1 = "N"  + str(ranger2.get())
                        sheet.range(location1).value = montantRea2.get()
                    if lot2.get() != "":
                        location1 = "B"  + str(ranger2.get())
                        sheet.range(location1).value = lot2.get()
                                      
                    Update6_1()
                                
                if choice == "Changer une facture existante":
                    ajouter(self, parent, controller)
                    
                    global ranger
                    global libelle
                    global contractant
                    global montantCon
                    global dateprevue
                    global montantRea
                
                        
                    button = ttk.Button(self, text = "Finaliser",
                                command = addition)
                    button.grid(row = 19, column = 1, padx = 10, pady = 10)
                
                elif choice == "Rajouter une nouvelle facture":
                    global sheet
                    ajouter2(self, parent, controller)
                    
                    global ranger2
                    global libelle2
                    global contractant2
                    global montantCon2
                    global dateprevue2
                    global montantRea2
                    
                    button = ttk.Button(self, text = "Finaliser",
                                command = addition2)
                    button.grid(row = 19, column = 1, padx = 10, pady = 10)
                        
            options = [
                "Changer une facture existante",
                "Rajouter une nouvelle facture"
            ]

            global clicked
            clicked = StringVar()
            clicked.set("Bonus options")

            drop2 = OptionMenu(self, clicked, *options, command = test)
            drop2.grid(row = 4, column = 1, padx = 10, pady = 1)
                
        
        display = ttk.Button(self, text = "Affichage", command = Display6_1)
        display.grid(row = 2, column = 1, padx = 5, pady = 1)
        
        button = ttk.Button(self, text ="StartPage",
                            command = lambda : controller.show_frame(StartPage))
        button.grid(row = 1, column = 0, padx = 10, pady = 1)
          
        button1 = ttk.Button(self, text ="Raccordement électrique",
                            command = lambda : controller.show_frame(Page1))
        button1.grid(row = 2, column = 0, padx = 10, pady = 1)
  
        button2 = ttk.Button(self, text ="Modules",
                            command = lambda : controller.show_frame(Page2))
        button2.grid(row = 3, column = 0, padx = 10, pady = 1)
  
        button3 = ttk.Button(self, text ="Frais de constructions divers",
                            command = lambda : controller.show_frame(Page3))
        button3.grid(row = 4, column = 0, padx = 10, pady = 1)
        
        button4 = ttk.Button(self, text ="Génie mécanique  - Structure/Fixation",
                            command = lambda : controller.show_frame(Page4))
        button4.grid(row = 5, column = 0, padx = 10, pady = 1)
  
        button5 = ttk.Button(self, text ="Génie éléctrique",
                            command = lambda : controller.show_frame(Page5))
        button5.grid(row = 6, column = 0, padx = 10, pady = 1)
        
        button6 = ttk.Button(self, text ="Terrassement/Voirie",
                            command = lambda : controller.show_frame(Page6))
        button6.grid(row = 7, column = 0, padx = 10, pady = 1)
  
  
# Driver Code
app = tkinterApp()
app.mainloop()
# Out:
# success
# success
# success
# success
# success
# success
# success
# success
# success
